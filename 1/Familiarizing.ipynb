# %%
import pandas as pd
dataset1=pd.read_csv('all_seasons.csv')
dataset1
# Out:
#        Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0               0  Randy Livingston               HOU  22.0         193.04
# 1               1  Gaylon Nickerson               WAS  28.0         190.50
# 2               2      George Lynch               VAN  26.0         203.20
# 3               3    George McCloud               LAL  30.0         203.20
# 4               4      George Zidek               DEN  23.0         213.36
# ...           ...               ...               ...   ...            ...
# 12839       12839       Joel Embiid               PHI  29.0         213.36
# 12840       12840   John Butler Jr.               POR  20.0         213.36
# 12841       12841      John Collins               ATL  25.0         205.74
# 12842       12842      Jericho Sims               NYK  24.0         208.28
# 12843       12843    JaMychal Green               GSW  33.0         205.74
#
# ...

# %%
import pandas as pd
dataset2=pd.read_csv('bank-full.csv')
dataset2
# Out:
#       age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0      58;"management";"married";"tertiary";"no";2143...
# 1      44;"technician";"single";"secondary";"no";29;"...
# 2      33;"entrepreneur";"married";"secondary";"no";2...
# 3      47;"blue-collar";"married";"unknown";"no";1506...
# 4      33;"unknown";"single";"unknown";"no";1;"no";"n...
# ...                                                  ...
# 45206  51;"technician";"married";"tertiary";"no";825;...
# 45207  71;"retired";"divorced";"primary";"no";1729;"n...
# 45208  72;"retired";"married";"secondary";"no";5715;"...
# 45209  57;"blue-collar";"married";"secondary";"no";66...
# 45210  37;"entrepreneur";"married";"secondary";"no";2...
#
# [45211 rows x 1 columns]

# %%
print("Shape of dataset 1:", dataset1.shape)
# Out:
# Shape of dataset 1: (12844, 22)

# %%
print("Shape of dataset 2:", dataset2.shape)
# Out:
# Shape of dataset 2: (45211, 1)

# %%
print("Columns in dataset 1:", dataset1.columns)
print("Columns in dataset 2:", dataset2.columns)
# Out:
# Columns in dataset 1: Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season'],
#       dtype='object')
# Columns in dataset 2: Index(['age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"'], dtype='object')

# %%
print("Data types in dataset 1:\n", dataset1.dtypes)
print("\nData types in dataset 2:\n", dataset2.dtypes)
# Out:
# Data types in dataset 1:
#  Unnamed: 0             int64
# player_name           object
# team_abbreviation     object
# age                  float64
# player_height        float64
# player_weight        float64
# college               object
# country               object
# draft_year            object
# draft_round           object
# draft_number          object
# gp                     int64
# pts                  float64
# reb                  float64
# ast                  float64
# net_rating           float64
# oreb_pct             float64
# dreb_pct             float64
# usg_pct              float64
# ts_pct               float64
# ast_pct              float64
# season                object
# dtype: object
#
# Data types in dataset 2:
#  age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"    object
# dtype: object

# %%
print("Missing values in dataset 1:\n", dataset1.isnull().sum())
print("\nMissing values in dataset 2:\n", dataset2.isnull().sum())
# Out:
# Missing values in dataset 1:
#  Unnamed: 0              0
# player_name             0
# team_abbreviation       0
# age                     0
# player_height           0
# player_weight           0
# college              1854
# country                 0
# draft_year              0
# draft_round             0
# draft_number            0
# gp                      0
# pts                     0
# reb                     0
# ast                     0
# net_rating              0
# oreb_pct                0
# dreb_pct                0
# usg_pct                 0
# ts_pct                  0
# ast_pct                 0
# season                  0
# dtype: int64
#
# Missing values in dataset 2:
#  age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"    0
# dtype: int64

# %%
print("Summary statistics for dataset 1:\n", dataset1.describe())
# Out:
# Summary statistics for dataset 1:
#           Unnamed: 0           age  player_height  player_weight            gp  \
# count  12844.000000  12844.000000   12844.000000   12844.000000  12844.000000
# mean    6421.500000     27.045313     200.555097     100.263279     51.154158
# std     3707.887763      4.339211       9.111090      12.426628     25.084904
# min        0.000000     18.000000     160.020000      60.327736      1.000000
# 25%     3210.750000     24.000000     193.040000      90.718400     31.000000
# 50%     6421.500000     26.000000     200.660000      99.790240     57.000000
# 75%     9632.250000     30.000000     208.280000     108.862080     73.000000
# max    12843.000000     44.000000     231.140000     163.293120     85.000000
#
#                 pts           reb           ast    net_rating      oreb_pct  \
# count  12844.000000  12844.000000  12844.000000  12844.000000  12844.000000
# mean       8.212582      3.558486      1.824681     -2.226339      0.054073
# ...

# %%
print("Summary statistics for dataset 1:\n", dataset2.describe())
# Out:
# Summary statistics for dataset 1:
#         age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# count                                               45211
# unique                                              45211
# top     37;"entrepreneur";"married";"secondary";"no";2...
# freq                                                    1
